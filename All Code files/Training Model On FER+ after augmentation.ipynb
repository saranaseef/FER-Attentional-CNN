# %%
import numpy as np

# %%
import torch

# %%
from __future__ import print_function
import argparse
import numpy  as np
from PIL import Image
import torch
import torch.nn as nn
import torch.nn.functional as F
import torchvision
import torch.optim as optim
from torch.utils.data import DataLoader, Dataset
from torch.utils.data.sampler import SubsetRandomSampler
from torchvision import transforms

# %%
import data_loaders

# %%
from data_loaders import Plain_Dataset, eval_data_dataloader

# %%
from deep_emotion import Deep_Emotion

# %%
device = torch.device("cuda:0" if torch.cuda.is_available() else "cpu")
# Out:
# /home/youssef/.local/lib/python3.8/site-packages/torch/cuda/__init__.py:138: UserWarning: CUDA initialization: The NVIDIA driver on your system is too old (found version 11070). Please update your GPU driver by downloading and installing a new version from the URL: http://www.nvidia.com/Download/index.aspx Alternatively, go to: https://pytorch.org to install a PyTorch version that has been compiled with your version of the CUDA driver. (Triggered internally at ../c10/cuda/CUDAFunctions.cpp:108.)
#   return torch._C._cuda_getDeviceCount() > 0

# %%
def Train(epochs,train_loader,val_loader,criterion,optmizer,device):
    '''
    Training Loop
    '''
    print("===================================Start Training===================================")
    for e in range(epochs):
        train_loss = 0
        validation_loss = 0
        train_correct = 0
        val_correct = 0
        # Train the model  #
        net.train()
        for data, labels in train_loader:
            data, labels = data.to(device), labels.to(device)
            optmizer.zero_grad()
            outputs = net(data)
            #print(outputs[0])
            #print(outputs[0])

            loss = criterion(outputs,labels)
            #print(labels[0])

            loss.backward()
            optmizer.step()
            train_loss += loss.item()
            _, preds = torch.max(outputs,1)
            train_correct += torch.sum(preds == labels.data)

        #validate the model#
        net.eval()
        for data,labels in val_loader:
            data, labels = data.to(device), labels.to(device)
            val_outputs = net(data)
            #print(val_outputs[0][3])
            #print(labels[0])
            val_loss = criterion(val_outputs, labels)
            validation_loss += val_loss.item()
            _, val_preds = torch.max(val_outputs,1)
            val_correct += torch.sum(val_preds == labels.data)

        train_loss = train_loss/len(train_dataset)
        train_acc = train_correct.double() / len(train_dataset)
        validation_loss =  validation_loss / len(validation_dataset)
        val_acc = val_correct.double() / len(validation_dataset)
        print('Epoch: {} \tTraining Loss: {:.8f} \tValidation Loss {:.8f} \tTraining Acuuarcy {:.3f}% \tValidation Acuuarcy {:.3f}%'
                                                           .format(e+1, train_loss,validation_loss,train_acc * 100, val_acc*100))

    torch.save(net.state_dict(),'deep_emotion-{}-{}-{}.pt'.format(epochs,batchsize,lr))
    print("===================================Training Finished===================================")

# %%
parser = argparse.ArgumentParser(description="Configuration of setup and training process")
parser.add_argument('-s', '--setup', type=bool, help='setup the dataset for the first time')
# Out:
# _StoreAction(option_strings=['-s', '--setup'], dest='setup', nargs=None, const=None, default=None, type=<class 'bool'>, choices=None, help='setup the dataset for the first time', metavar=None)

# %%
parser.add_argument('-d', '--data', type=str,required= True,
                               help='data folder that contains data files that downloaded from kaggle (train.csv and test.csv)')
# Out:
# _StoreAction(option_strings=['-d', '--data'], dest='data', nargs=None, const=None, default=None, type=<class 'str'>, choices=None, help='data folder that contains data files that downloaded from kaggle (train.csv and test.csv)', metavar=None)

# %%
parser.add_argument('-hparams', '--hyperparams', type=bool,
                               help='True when changing the hyperparameters e.g (batch size, LR, num. of epochs)')
# Out:
# _StoreAction(option_strings=['-hparams', '--hyperparams'], dest='hyperparams', nargs=None, const=None, default=None, type=<class 'bool'>, choices=None, help='True when changing the hyperparameters e.g (batch size, LR, num. of epochs)', metavar=None)

# %%
parser.add_argument('-e', '--epochs', type= int, help= 'number of epochs')
parser.add_argument('-lr', '--learning_rate', type= float, help= 'value of learning rate')
parser.add_argument('-bs', '--batch_size', type= int, help= 'training/validation batch size')
parser.add_argument('-t', '--train', type=bool, help='True when training')
# Out:
# _StoreAction(option_strings=['-t', '--train'], dest='train', nargs=None, const=None, default=None, type=<class 'bool'>, choices=None, help='True when training', metavar=None)

# %%
epochs = 2000
lr = 0.001
batchsize = 128

# %%
net = Deep_Emotion()

# %%
net.to(device)
# Out:
# Deep_Emotion(
#   (conv1): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1))
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (dropout2): Dropout(p=0.25, inplace=False)
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (dropout3): Dropout(p=0.25, inplace=False)
#   (conv4): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (dropout4): Dropout(p=0.25, inplace=False)
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv5): Conv2d(50, 50, kernel_size=(2, 2), stride=(1, 1))
#   (conv6): Conv2d(50, 10, kernel_size=(2, 2), stride=(1, 1))
#   (pool6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (norm): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=810, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=8, bias=True)
#   (softmax): Softmax(dim=1)
#   (localization): Sequential(
#     (0): Conv2d(3, 15, kernel_size=(7, 7), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(15, 10, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU(inplace=True)
#   )
#   (fc_loc): Sequential(
#     (0): Linear(in_features=640, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=32, out_features=6, bias=True)
#   )
# )

# %%
print("Model archticture: ", net)
# Out:
# Model archticture:  Deep_Emotion(
#   (conv1): Conv2d(3, 10, kernel_size=(3, 3), stride=(1, 1))
#   (dropout1): Dropout(p=0.25, inplace=False)
#   (conv2): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (dropout2): Dropout(p=0.25, inplace=False)
#   (pool2): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv3): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (dropout3): Dropout(p=0.25, inplace=False)
#   (conv4): Conv2d(10, 10, kernel_size=(3, 3), stride=(1, 1))
#   (dropout4): Dropout(p=0.25, inplace=False)
#   (pool4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (conv5): Conv2d(50, 50, kernel_size=(2, 2), stride=(1, 1))
#   (conv6): Conv2d(50, 10, kernel_size=(2, 2), stride=(1, 1))
#   (pool6): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#   (norm): BatchNorm2d(10, eps=1e-05, momentum=0.1, affine=True, track_running_stats=True)
#   (fc1): Linear(in_features=810, out_features=100, bias=True)
#   (fc2): Linear(in_features=100, out_features=8, bias=True)
#   (softmax): Softmax(dim=1)
#   (localization): Sequential(
#     (0): Conv2d(3, 15, kernel_size=(7, 7), stride=(1, 1))
#     (1): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (2): ReLU(inplace=True)
#     (3): Conv2d(15, 10, kernel_size=(5, 5), stride=(1, 1))
#     (4): MaxPool2d(kernel_size=2, stride=2, padding=0, dilation=1, ceil_mode=False)
#     (5): ReLU(inplace=True)
#   )
#   (fc_loc): Sequential(
#     (0): Linear(in_features=640, out_features=32, bias=True)
#     (1): ReLU(inplace=True)
#     (2): Linear(in_features=32, out_features=6, bias=True)
#   )
# )

# %%
transformation= transforms.Compose([transforms.ToTensor(),transforms.Normalize((0.5,),(0.5,))])

# %%
traincsv_file = "data2" + "/"+"train.csv"
validationcsv_file = "data2" + "/"+"val.csv"

# %%
train_img_dir = "data2"+"/"+"train/"

# %%
validation_img_dir = "data2"+"/"+"val/"

# %%
train_dataset= Plain_Dataset(csv_file=traincsv_file, img_dir = train_img_dir, datatype = 'train', transform = transformation)

# %%
validation_dataset= Plain_Dataset(csv_file=validationcsv_file, img_dir = validation_img_dir, datatype = 'val', transform = transformation)

# %%
train_loader= DataLoader(train_dataset,batch_size=batchsize,shuffle = True,num_workers=0)
val_loader=   DataLoader(validation_dataset,batch_size=batchsize,shuffle = True,num_workers=0)

# %%
criterion= nn.CrossEntropyLoss()
optmizer= optim.Adam(net.parameters(),lr= 0.00001, weight_decay = 0.001)

# %%
Train(epochs, train_loader, val_loader, criterion, optmizer, device)
# Out:
# ===================================Start Training===================================
# /home/youssef/.local/lib/python3.8/site-packages/torch/nn/functional.py:4358: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /home/youssef/.local/lib/python3.8/site-packages/torch/nn/functional.py:4296: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# Epoch: 25 	Training Loss: 0.01121398 	Validation Loss 0.01309254 	Training Acuuarcy 84.453% 	Validation Acuuarcy 65.846%
# Epoch: 26 	Training Loss: 0.01121005 	Validation Loss 0.01317534 	Training Acuuarcy 84.382% 	Validation Acuuarcy 65.213%
# Epoch: 27 	Training Loss: 0.01120518 	Validation Loss 0.01316965 	Training Acuuarcy 84.618% 	Validation Acuuarcy 64.826%
# Epoch: 28 	Training Loss: 0.01120232 	Validation Loss 0.01322149 	Training Acuuarcy 84.614% 	Validation Acuuarcy 64.017%
# Epoch: 29 	Training Loss: 0.01120726 	Validation Loss 0.01318397 	Training Acuuarcy 84.490% 	Validation Acuuarcy 65.037%
# Epoch: 30 	Training Loss: 0.01121457 	Validation Loss 0.01322372 	Training Acuuarcy 84.483% 	Validation Acuuarcy 64.017%
# Epoch: 31 	Training Loss: 0.01121228 	Validation Loss 0.01313422 	Training Acuuarcy 84.480% 	Validation Acuuarcy 65.600%
# Epoch: 32 	Training Loss: 0.01120561 	Validation Loss 0.01316125 	Training Acuuarcy 84.641% 	Validation Acuuarcy 64.896%
# Epoch: 33 	Training Loss: 0.01122491 	Validation Loss 0.01314978 	Training Acuuarcy 84.399% 	Validation Acuuarcy 64.896%
# Epoch: 34 	Training Loss: 0.01121221 	Validation Loss 0.01318743 	Training Acuuarcy 84.422% 	Validation Acuuarcy 64.263%
# Epoch: 35 	Training Loss: 0.01122998 	Validation Loss 0.01313176 	Training Acuuarcy 84.250% 	Validation Acuuarcy 65.811%
# Epoch: 36 	Training Loss: 0.01122002 	Validation Loss 0.01322836 	Training Acuuarcy 84.385% 	Validation Acuuarcy 64.158%
# Epoch: 37 	Training Loss: 0.01121720 	Validation Loss 0.01313802 	Training Acuuarcy 84.372% 	Validation Acuuarcy 65.846%
# Epoch: 38 	Training Loss: 0.01121494 	Validation Loss 0.01320386 	Training Acuuarcy 84.368% 	Validation Acuuarcy 64.298%
# Epoch: 39 	Training Loss: 0.01122083 	Validation Loss 0.01316058 	Training Acuuarcy 84.362% 	Validation Acuuarcy 65.107%
# Epoch: 40 	Training Loss: 0.01120922 	Validation Loss 0.01310392 	Training Acuuarcy 84.537% 	Validation Acuuarcy 65.459%
# Epoch: 41 	Training Loss: 0.01122531 	Validation Loss 0.01313258 	Training Acuuarcy 84.378% 	Validation Acuuarcy 65.389%
# Epoch: 42 	Training Loss: 0.01121939 	Validation Loss 0.01308643 	Training Acuuarcy 84.274% 	Validation Acuuarcy 64.896%
# Epoch: 43 	Training Loss: 0.01122308 	Validation Loss 0.01310470 	Training Acuuarcy 84.294% 	Validation Acuuarcy 64.896%
# Epoch: 44 	Training Loss: 0.01121003 	Validation Loss 0.01312177 	Training Acuuarcy 84.530% 	Validation Acuuarcy 65.142%
# Epoch: 45 	Training Loss: 0.01121715 	Validation Loss 0.01313859 	Training Acuuarcy 84.466% 	Validation Acuuarcy 65.846%
# Epoch: 46 	Training Loss: 0.01119645 	Validation Loss 0.01311956 	Training Acuuarcy 84.857% 	Validation Acuuarcy 64.685%
# Epoch: 47 	Training Loss: 0.01121800 	Validation Loss 0.01312303 	Training Acuuarcy 84.483% 	Validation Acuuarcy 65.529%
# Epoch: 48 	Training Loss: 0.01121630 	Validation Loss 0.01317682 	Training Acuuarcy 84.469% 	Validation Acuuarcy 65.002%
# Epoch: 49 	Training Loss: 0.01121493 	Validation Loss 0.01315318 	Training Acuuarcy 84.486% 	Validation Acuuarcy 65.107%
# Epoch: 50 	Training Loss: 0.01121040 	Validation Loss 0.01313831 	Training Acuuarcy 84.507% 	Validation Acuuarcy 65.459%
# Epoch: 51 	Training Loss: 0.01122326 	Validation Loss 0.01310390 	Training Acuuarcy 84.335% 	Validation Acuuarcy 65.389%
# Epoch: 52 	Training Loss: 0.01121642 	Validation Loss 0.01312799 	Training Acuuarcy 84.422% 	Validation Acuuarcy 65.459%
# Epoch: 53 	Training Loss: 0.01121399 	Validation Loss 0.01313326 	Training Acuuarcy 84.402% 	Validation Acuuarcy 65.424%
# Epoch: 54 	Training Loss: 0.01121835 	Validation Loss 0.01315036 	Training Acuuarcy 84.378% 	Validation Acuuarcy 65.248%
# Epoch: 55 	Training Loss: 0.01120723 	Validation Loss 0.01317830 	Training Acuuarcy 84.560% 	Validation Acuuarcy 64.896%
# Epoch: 56 	Training Loss: 0.01123081 	Validation Loss 0.01306212 	Training Acuuarcy 84.193% 	Validation Acuuarcy 65.529%
# Epoch: 57 	Training Loss: 0.01122226 	Validation Loss 0.01317455 	Training Acuuarcy 84.378% 	Validation Acuuarcy 65.248%
# Epoch: 58 	Training Loss: 0.01120380 	Validation Loss 0.01312273 	Training Acuuarcy 84.648% 	Validation Acuuarcy 65.565%
# Epoch: 59 	Training Loss: 0.01122408 	Validation Loss 0.01316852 	Training Acuuarcy 84.294% 	Validation Acuuarcy 64.720%
# Epoch: 60 	Training Loss: 0.01120967 	Validation Loss 0.01313034 	Training Acuuarcy 84.530% 	Validation Acuuarcy 65.494%
# Epoch: 61 	Training Loss: 0.01121448 	Validation Loss 0.01324904 	Training Acuuarcy 84.483% 	Validation Acuuarcy 63.841%
# Epoch: 62 	Training Loss: 0.01120919 	Validation Loss 0.01305471 	Training Acuuarcy 84.486% 	Validation Acuuarcy 66.057%
# Epoch: 63 	Training Loss: 0.01122952 	Validation Loss 0.01323194 	Training Acuuarcy 84.156% 	Validation Acuuarcy 64.298%
# Epoch: 64 	Training Loss: 0.01121799 	Validation Loss 0.01310911 	Training Acuuarcy 84.507% 	Validation Acuuarcy 65.670%
# Epoch: 65 	Training Loss: 0.01119932 	Validation Loss 0.01308815 	Training Acuuarcy 84.776% 	Validation Acuuarcy 65.951%
# Epoch: 66 	Training Loss: 0.01121736 	Validation Loss 0.01321321 	Training Acuuarcy 84.490% 	Validation Acuuarcy 64.650%
# Epoch: 67 	Training Loss: 0.01121320 	Validation Loss 0.01319627 	Training Acuuarcy 84.571% 	Validation Acuuarcy 64.580%
# Epoch: 68 	Training Loss: 0.01120995 	Validation Loss 0.01313302 	Training Acuuarcy 84.473% 	Validation Acuuarcy 65.283%
# Epoch: 69 	Training Loss: 0.01121617 	Validation Loss 0.01320899 	Training Acuuarcy 84.453% 	Validation Acuuarcy 64.474%
# Epoch: 268 	Training Loss: 0.01120212 	Validation Loss 0.01318837 	Training Acuuarcy 84.894% 	Validation Acuuarcy 65.565%
# Epoch: 269 	Training Loss: 0.01118638 	Validation Loss 0.01323931 	Training Acuuarcy 85.197% 	Validation Acuuarcy 64.720%
# Epoch: 270 	Training Loss: 0.01119312 	Validation Loss 0.01325548 	Training Acuuarcy 84.968% 	Validation Acuuarcy 63.735%
# Epoch: 271 	Training Loss: 0.01119090 	Validation Loss 0.01322248 	Training Acuuarcy 85.153% 	Validation Acuuarcy 64.650%
# Epoch: 272 	Training Loss: 0.01119039 	Validation Loss 0.01316431 	Training Acuuarcy 85.116% 	Validation Acuuarcy 66.022%
# Epoch: 273 	Training Loss: 0.01120481 	Validation Loss 0.01316618 	Training Acuuarcy 84.874% 	Validation Acuuarcy 65.037%
# Epoch: 274 	Training Loss: 0.01119661 	Validation Loss 0.01318345 	Training Acuuarcy 85.066% 	Validation Acuuarcy 64.931%
# Epoch: 275 	Training Loss: 0.01118903 	Validation Loss 0.01319620 	Training Acuuarcy 85.164% 	Validation Acuuarcy 65.389%
# Epoch: 276 	Training Loss: 0.01120248 	Validation Loss 0.01315188 	Training Acuuarcy 84.877% 	Validation Acuuarcy 65.494%
# Epoch: 277 	Training Loss: 0.01119084 	Validation Loss 0.01320848 	Training Acuuarcy 85.174% 	Validation Acuuarcy 65.248%
# Epoch: 278 	Training Loss: 0.01118563 	Validation Loss 0.01325559 	Training Acuuarcy 85.167% 	Validation Acuuarcy 64.052%
# Epoch: 279 	Training Loss: 0.01119170 	Validation Loss 0.01321074 	Training Acuuarcy 85.066% 	Validation Acuuarcy 65.389%
# Epoch: 280 	Training Loss: 0.01118273 	Validation Loss 0.01318186 	Training Acuuarcy 85.224% 	Validation Acuuarcy 64.861%
# Epoch: 281 	Training Loss: 0.01118789 	Validation Loss 0.01317083 	Training Acuuarcy 85.083% 	Validation Acuuarcy 65.002%
# Epoch: 282 	Training Loss: 0.01117837 	Validation Loss 0.01317881 	Training Acuuarcy 85.191% 	Validation Acuuarcy 65.529%
# Epoch: 283 	Training Loss: 0.01120047 	Validation Loss 0.01321252 	Training Acuuarcy 84.921% 	Validation Acuuarcy 65.142%
# Epoch: 284 	Training Loss: 0.01119033 	Validation Loss 0.01319906 	Training Acuuarcy 85.005% 	Validation Acuuarcy 64.967%
# Epoch: 285 	Training Loss: 0.01119714 	Validation Loss 0.01318592 	Training Acuuarcy 84.961% 	Validation Acuuarcy 65.811%
# Epoch: 286 	Training Loss: 0.01118655 	Validation Loss 0.01324708 	Training Acuuarcy 85.056% 	Validation Acuuarcy 64.193%
# Epoch: 287 	Training Loss: 0.01117923 	Validation Loss 0.01325289 	Training Acuuarcy 85.244% 	Validation Acuuarcy 64.228%
# Epoch: 288 	Training Loss: 0.01120199 	Validation Loss 0.01324663 	Training Acuuarcy 84.904% 	Validation Acuuarcy 63.524%
# Epoch: 289 	Training Loss: 0.01119092 	Validation Loss 0.01324344 	Training Acuuarcy 85.120% 	Validation Acuuarcy 64.931%
# Epoch: 290 	Training Loss: 0.01118794 	Validation Loss 0.01325654 	Training Acuuarcy 85.127% 	Validation Acuuarcy 64.122%
# Epoch: 291 	Training Loss: 0.01118240 	Validation Loss 0.01325161 	Training Acuuarcy 85.184% 	Validation Acuuarcy 64.052%
# Epoch: 292 	Training Loss: 0.01118210 	Validation Loss 0.01321346 	Training Acuuarcy 85.147% 	Validation Acuuarcy 64.017%
# Epoch: 293 	Training Loss: 0.01118202 	Validation Loss 0.01325961 	Training Acuuarcy 85.100% 	Validation Acuuarcy 64.896%
# Epoch: 294 	Training Loss: 0.01120081 	Validation Loss 0.01324402 	Training Acuuarcy 84.931% 	Validation Acuuarcy 64.369%
# Epoch: 295 	Training Loss: 0.01119340 	Validation Loss 0.01322649 	Training Acuuarcy 85.063% 	Validation Acuuarcy 64.052%
# Epoch: 296 	Training Loss: 0.01120221 	Validation Loss 0.01321949 	Training Acuuarcy 84.806% 	Validation Acuuarcy 65.002%
# Epoch: 297 	Training Loss: 0.01120934 	Validation Loss 0.01320099 	Training Acuuarcy 84.877% 	Validation Acuuarcy 64.298%
# Epoch: 298 	Training Loss: 0.01118433 	Validation Loss 0.01320686 	Training Acuuarcy 85.164% 	Validation Acuuarcy 64.439%
# Epoch: 299 	Training Loss: 0.01118983 	Validation Loss 0.01315831 	Training Acuuarcy 85.056% 	Validation Acuuarcy 65.635%
# Epoch: 300 	Training Loss: 0.01119987 	Validation Loss 0.01320539 	Training Acuuarcy 84.904% 	Validation Acuuarcy 64.474%
# Epoch: 301 	Training Loss: 0.01118654 	Validation Loss 0.01332307 	Training Acuuarcy 85.103% 	Validation Acuuarcy 63.806%
# Epoch: 302 	Training Loss: 0.01117851 	Validation Loss 0.01321821 	Training Acuuarcy 85.160% 	Validation Acuuarcy 63.876%
# Epoch: 303 	Training Loss: 0.01118086 	Validation Loss 0.01318322 	Training Acuuarcy 85.204% 	Validation Acuuarcy 64.544%
# Epoch: 304 	Training Loss: 0.01118780 	Validation Loss 0.01322883 	Training Acuuarcy 85.204% 	Validation Acuuarcy 64.369%
# Epoch: 305 	Training Loss: 0.01119039 	Validation Loss 0.01325542 	Training Acuuarcy 85.120% 	Validation Acuuarcy 64.298%
# Epoch: 306 	Training Loss: 0.01119304 	Validation Loss 0.01320480 	Training Acuuarcy 85.066% 	Validation Acuuarcy 64.931%
# Epoch: 307 	Training Loss: 0.01119050 	Validation Loss 0.01320048 	Training Acuuarcy 85.083% 	Validation Acuuarcy 63.771%
# Epoch: 308 	Training Loss: 0.01119699 	Validation Loss 0.01327945 	Training Acuuarcy 84.998% 	Validation Acuuarcy 64.193%
# Epoch: 309 	Training Loss: 0.01119148 	Validation Loss 0.01327119 	Training Acuuarcy 85.147% 	Validation Acuuarcy 64.263%
# Epoch: 310 	Training Loss: 0.01119733 	Validation Loss 0.01315065 	Training Acuuarcy 84.955% 	Validation Acuuarcy 64.474%
# Epoch: 311 	Training Loss: 0.01120211 	Validation Loss 0.01325901 	Training Acuuarcy 84.968% 	Validation Acuuarcy 63.771%
# Epoch: 379 	Training Loss: 0.01118042 	Validation Loss 0.01320787 	Training Acuuarcy 85.261% 	Validation Acuuarcy 65.002%
# Epoch: 380 	Training Loss: 0.01118887 	Validation Loss 0.01321306 	Training Acuuarcy 85.204% 	Validation Acuuarcy 64.967%
# Epoch: 381 	Training Loss: 0.01118248 	Validation Loss 0.01322025 	Training Acuuarcy 85.265% 	Validation Acuuarcy 64.193%
# Epoch: 382 	Training Loss: 0.01118598 	Validation Loss 0.01318152 	Training Acuuarcy 85.255% 	Validation Acuuarcy 65.107%
# Epoch: 383 	Training Loss: 0.01119305 	Validation Loss 0.01323956 	Training Acuuarcy 85.221% 	Validation Acuuarcy 63.947%
# Epoch: 384 	Training Loss: 0.01118920 	Validation Loss 0.01327875 	Training Acuuarcy 85.177% 	Validation Acuuarcy 64.193%
# Epoch: 385 	Training Loss: 0.01118597 	Validation Loss 0.01317168 	Training Acuuarcy 85.288% 	Validation Acuuarcy 64.931%
# Epoch: 386 	Training Loss: 0.01118106 	Validation Loss 0.01326032 	Training Acuuarcy 85.325% 	Validation Acuuarcy 65.283%
# Epoch: 387 	Training Loss: 0.01116124 	Validation Loss 0.01327019 	Training Acuuarcy 85.635% 	Validation Acuuarcy 63.454%
# Epoch: 388 	Training Loss: 0.01117737 	Validation Loss 0.01326277 	Training Acuuarcy 85.295% 	Validation Acuuarcy 64.298%
# ...
# Epoch: 1872 	Training Loss: 0.01106254 	Validation Loss 0.01327437 	Training Acuuarcy 87.172% 	Validation Acuuarcy 63.876%
# Epoch: 1873 	Training Loss: 0.01104688 	Validation Loss 0.01331628 	Training Acuuarcy 87.600% 	Validation Acuuarcy 63.560%
# Epoch: 1874 	Training Loss: 0.01104550 	Validation Loss 0.01336049 	Training Acuuarcy 87.495% 	Validation Acuuarcy 63.067%
# Epoch: 1875 	Training Loss: 0.01104124 	Validation Loss 0.01328867 	Training Acuuarcy 87.657% 	Validation Acuuarcy 64.017%
# Epoch: 1876 	Training Loss: 0.01103567 	Validation Loss 0.01333285 	Training Acuuarcy 87.799% 	Validation Acuuarcy 63.595%
# Epoch: 1877 	Training Loss: 0.01104286 	Validation Loss 0.01329270 	Training Acuuarcy 87.580% 	Validation Acuuarcy 64.439%
# Epoch: 1878 	Training Loss: 0.01105794 	Validation Loss 0.01330427 	Training Acuuarcy 87.212% 	Validation Acuuarcy 64.333%
# Epoch: 1879 	Training Loss: 0.01104335 	Validation Loss 0.01335351 	Training Acuuarcy 87.539% 	Validation Acuuarcy 63.489%
# Epoch: 1880 	Training Loss: 0.01106354 	Validation Loss 0.01337205 	Training Acuuarcy 87.320% 	Validation Acuuarcy 63.876%
# Epoch: 1881 	Training Loss: 0.01104842 	Validation Loss 0.01333748 	Training Acuuarcy 87.394% 	Validation Acuuarcy 63.806%
# Epoch: 1882 	Training Loss: 0.01105674 	Validation Loss 0.01333565 	Training Acuuarcy 87.290% 	Validation Acuuarcy 63.454%
# Epoch: 1883 	Training Loss: 0.01104934 	Validation Loss 0.01332365 	Training Acuuarcy 87.489% 	Validation Acuuarcy 63.665%
# Epoch: 1884 	Training Loss: 0.01105448 	Validation Loss 0.01333870 	Training Acuuarcy 87.465% 	Validation Acuuarcy 63.454%
# Epoch: 1885 	Training Loss: 0.01104002 	Validation Loss 0.01326945 	Training Acuuarcy 87.708% 	Validation Acuuarcy 64.052%
# Epoch: 1886 	Training Loss: 0.01106015 	Validation Loss 0.01333597 	Training Acuuarcy 87.175% 	Validation Acuuarcy 63.595%
# Epoch: 1887 	Training Loss: 0.01103920 	Validation Loss 0.01330807 	Training Acuuarcy 87.698% 	Validation Acuuarcy 63.454%
# Epoch: 1888 	Training Loss: 0.01104942 	Validation Loss 0.01328659 	Training Acuuarcy 87.472% 	Validation Acuuarcy 63.911%
# Epoch: 1889 	Training Loss: 0.01104930 	Validation Loss 0.01329181 	Training Acuuarcy 87.505% 	Validation Acuuarcy 64.720%
# Epoch: 1890 	Training Loss: 0.01103843 	Validation Loss 0.01328499 	Training Acuuarcy 87.573% 	Validation Acuuarcy 64.263%
# Epoch: 1891 	Training Loss: 0.01104031 	Validation Loss 0.01326743 	Training Acuuarcy 87.563% 	Validation Acuuarcy 64.122%
# Epoch: 1892 	Training Loss: 0.01105113 	Validation Loss 0.01336980 	Training Acuuarcy 87.441% 	Validation Acuuarcy 63.208%
# Epoch: 1893 	Training Loss: 0.01103908 	Validation Loss 0.01328935 	Training Acuuarcy 87.600% 	Validation Acuuarcy 64.158%
# Epoch: 1894 	Training Loss: 0.01104625 	Validation Loss 0.01327351 	Training Acuuarcy 87.445% 	Validation Acuuarcy 64.193%
# Epoch: 1895 	Training Loss: 0.01105302 	Validation Loss 0.01332335 	Training Acuuarcy 87.276% 	Validation Acuuarcy 64.158%
# Epoch: 1896 	Training Loss: 0.01106892 	Validation Loss 0.01334082 	Training Acuuarcy 87.185% 	Validation Acuuarcy 64.263%
# Epoch: 1897 	Training Loss: 0.01103497 	Validation Loss 0.01330856 	Training Acuuarcy 87.698% 	Validation Acuuarcy 64.087%
# Epoch: 1898 	Training Loss: 0.01105037 	Validation Loss 0.01337212 	Training Acuuarcy 87.418% 	Validation Acuuarcy 63.489%
# Epoch: 1899 	Training Loss: 0.01104343 	Validation Loss 0.01330400 	Training Acuuarcy 87.505% 	Validation Acuuarcy 63.419%
# Epoch: 1900 	Training Loss: 0.01103991 	Validation Loss 0.01331488 	Training Acuuarcy 87.512% 	Validation Acuuarcy 64.122%
# Epoch: 1901 	Training Loss: 0.01104765 	Validation Loss 0.01335352 	Training Acuuarcy 87.613% 	Validation Acuuarcy 63.665%
# Epoch: 1902 	Training Loss: 0.01104435 	Validation Loss 0.01329692 	Training Acuuarcy 87.593% 	Validation Acuuarcy 64.369%
# Epoch: 1903 	Training Loss: 0.01105865 	Validation Loss 0.01333165 	Training Acuuarcy 87.310% 	Validation Acuuarcy 62.891%
# Epoch: 1904 	Training Loss: 0.01106180 	Validation Loss 0.01331870 	Training Acuuarcy 87.273% 	Validation Acuuarcy 63.313%
# Epoch: 1905 	Training Loss: 0.01104512 	Validation Loss 0.01327932 	Training Acuuarcy 87.539% 	Validation Acuuarcy 64.333%
# Epoch: 1906 	Training Loss: 0.01103818 	Validation Loss 0.01333203 	Training Acuuarcy 87.701% 	Validation Acuuarcy 63.630%
# Epoch: 1907 	Training Loss: 0.01105306 	Validation Loss 0.01330500 	Training Acuuarcy 87.431% 	Validation Acuuarcy 64.333%
# Epoch: 1908 	Training Loss: 0.01105459 	Validation Loss 0.01326505 	Training Acuuarcy 87.371% 	Validation Acuuarcy 64.052%
# Epoch: 1909 	Training Loss: 0.01104857 	Validation Loss 0.01337391 	Training Acuuarcy 87.465% 	Validation Acuuarcy 63.524%
# Epoch: 1910 	Training Loss: 0.01104512 	Validation Loss 0.01325003 	Training Acuuarcy 87.580% 	Validation Acuuarcy 64.263%
# Epoch: 1911 	Training Loss: 0.01104849 	Validation Loss 0.01332886 	Training Acuuarcy 87.472% 	Validation Acuuarcy 63.560%
# Epoch: 1912 	Training Loss: 0.01104312 	Validation Loss 0.01328019 	Training Acuuarcy 87.553% 	Validation Acuuarcy 64.333%
# Epoch: 1913 	Training Loss: 0.01104365 	Validation Loss 0.01326988 	Training Acuuarcy 87.600% 	Validation Acuuarcy 64.369%
# Epoch: 1914 	Training Loss: 0.01105643 	Validation Loss 0.01331636 	Training Acuuarcy 87.367% 	Validation Acuuarcy 63.384%
# Epoch: 1915 	Training Loss: 0.01105476 	Validation Loss 0.01334166 	Training Acuuarcy 87.404% 	Validation Acuuarcy 62.962%
# Epoch: 1916 	Training Loss: 0.01105874 	Validation Loss 0.01330329 	Training Acuuarcy 87.381% 	Validation Acuuarcy 64.333%
# Epoch: 1917 	Training Loss: 0.01103896 	Validation Loss 0.01330028 	Training Acuuarcy 87.573% 	Validation Acuuarcy 63.806%
# Epoch: 1918 	Training Loss: 0.01105072 	Validation Loss 0.01329720 	Training Acuuarcy 87.431% 	Validation Acuuarcy 63.349%
# Epoch: 1919 	Training Loss: 0.01104992 	Validation Loss 0.01324787 	Training Acuuarcy 87.475% 	Validation Acuuarcy 64.580%
# Epoch: 1920 	Training Loss: 0.01104318 	Validation Loss 0.01337494 	Training Acuuarcy 87.566% 	Validation Acuuarcy 62.926%
# Epoch: 1921 	Training Loss: 0.01104416 	Validation Loss 0.01334506 	Training Acuuarcy 87.556% 	Validation Acuuarcy 63.173%
# Epoch: 1922 	Training Loss: 0.01104866 	Validation Loss 0.01331679 	Training Acuuarcy 87.438% 	Validation Acuuarcy 63.454%
# Epoch: 1923 	Training Loss: 0.01104675 	Validation Loss 0.01336170 	Training Acuuarcy 87.569% 	Validation Acuuarcy 62.997%
# Epoch: 1924 	Training Loss: 0.01104777 	Validation Loss 0.01330661 	Training Acuuarcy 87.455% 	Validation Acuuarcy 63.560%
# Epoch: 1925 	Training Loss: 0.01103584 	Validation Loss 0.01335296 	Training Acuuarcy 87.725% 	Validation Acuuarcy 63.384%
# Epoch: 1926 	Training Loss: 0.01105221 	Validation Loss 0.01334188 	Training Acuuarcy 87.431% 	Validation Acuuarcy 63.032%
# Epoch: 1927 	Training Loss: 0.01103794 	Validation Loss 0.01335439 	Training Acuuarcy 87.627% 	Validation Acuuarcy 63.067%
# Epoch: 1928 	Training Loss: 0.01104367 	Validation Loss 0.01329186 	Training Acuuarcy 87.573% 	Validation Acuuarcy 63.349%
# Epoch: 1929 	Training Loss: 0.01103825 	Validation Loss 0.01331729 	Training Acuuarcy 87.684% 	Validation Acuuarcy 63.700%
# Epoch: 1930 	Training Loss: 0.01104685 	Validation Loss 0.01328065 	Training Acuuarcy 87.438% 	Validation Acuuarcy 63.700%
# Epoch: 1931 	Training Loss: 0.01104555 	Validation Loss 0.01335789 	Training Acuuarcy 87.472% 	Validation Acuuarcy 63.208%
# Epoch: 1932 	Training Loss: 0.01104817 	Validation Loss 0.01325727 	Training Acuuarcy 87.556% 	Validation Acuuarcy 63.982%
# Epoch: 1933 	Training Loss: 0.01105086 	Validation Loss 0.01325074 	Training Acuuarcy 87.388% 	Validation Acuuarcy 64.931%
# Epoch: 1934 	Training Loss: 0.01105166 	Validation Loss 0.01332476 	Training Acuuarcy 87.371% 	Validation Acuuarcy 63.489%
# Epoch: 1935 	Training Loss: 0.01105492 	Validation Loss 0.01330195 	Training Acuuarcy 87.384% 	Validation Acuuarcy 64.333%
# Epoch: 1936 	Training Loss: 0.01104681 	Validation Loss 0.01327694 	Training Acuuarcy 87.492% 	Validation Acuuarcy 64.122%
# Epoch: 1937 	Training Loss: 0.01104364 	Validation Loss 0.01332336 	Training Acuuarcy 87.576% 	Validation Acuuarcy 63.278%
# Epoch: 1938 	Training Loss: 0.01103333 	Validation Loss 0.01326735 	Training Acuuarcy 87.671% 	Validation Acuuarcy 64.650%
# Epoch: 1939 	Training Loss: 0.01103834 	Validation Loss 0.01330748 	Training Acuuarcy 87.664% 	Validation Acuuarcy 64.228%
# Epoch: 1940 	Training Loss: 0.01103798 	Validation Loss 0.01330246 	Training Acuuarcy 87.583% 	Validation Acuuarcy 63.876%
# Epoch: 1941 	Training Loss: 0.01105013 	Validation Loss 0.01326907 	Training Acuuarcy 87.479% 	Validation Acuuarcy 64.615%
# Epoch: 1942 	Training Loss: 0.01103842 	Validation Loss 0.01334417 	Training Acuuarcy 87.681% 	Validation Acuuarcy 63.173%
# Epoch: 1943 	Training Loss: 0.01105246 	Validation Loss 0.01329365 	Training Acuuarcy 87.377% 	Validation Acuuarcy 64.298%
# Epoch: 1944 	Training Loss: 0.01107037 	Validation Loss 0.01333258 	Training Acuuarcy 87.243% 	Validation Acuuarcy 63.735%
# Epoch: 1945 	Training Loss: 0.01104944 	Validation Loss 0.01332594 	Training Acuuarcy 87.448% 	Validation Acuuarcy 63.806%
# Epoch: 1946 	Training Loss: 0.01103465 	Validation Loss 0.01331588 	Training Acuuarcy 87.667% 	Validation Acuuarcy 63.735%
# Epoch: 1947 	Training Loss: 0.01104015 	Validation Loss 0.01330113 	Training Acuuarcy 87.559% 	Validation Acuuarcy 63.806%
# Epoch: 1948 	Training Loss: 0.01103961 	Validation Loss 0.01329713 	Training Acuuarcy 87.448% 	Validation Acuuarcy 63.665%
# Epoch: 1949 	Training Loss: 0.01105157 	Validation Loss 0.01329912 	Training Acuuarcy 87.539% 	Validation Acuuarcy 64.122%
# Epoch: 1950 	Training Loss: 0.01105154 	Validation Loss 0.01335360 	Training Acuuarcy 87.418% 	Validation Acuuarcy 63.138%
# Epoch: 1951 	Training Loss: 0.01105591 	Validation Loss 0.01324952 	Training Acuuarcy 87.468% 	Validation Acuuarcy 64.017%
# Epoch: 1952 	Training Loss: 0.01104514 	Validation Loss 0.01332950 	Training Acuuarcy 87.596% 	Validation Acuuarcy 63.524%
# Epoch: 1953 	Training Loss: 0.01104040 	Validation Loss 0.01327260 	Training Acuuarcy 87.607% 	Validation Acuuarcy 64.158%
# Epoch: 1954 	Training Loss: 0.01103474 	Validation Loss 0.01334106 	Training Acuuarcy 87.620% 	Validation Acuuarcy 64.158%
# Epoch: 1955 	Training Loss: 0.01103854 	Validation Loss 0.01329510 	Training Acuuarcy 87.559% 	Validation Acuuarcy 64.439%
# Epoch: 1956 	Training Loss: 0.01104845 	Validation Loss 0.01330615 	Training Acuuarcy 87.404% 	Validation Acuuarcy 63.524%
# Epoch: 1957 	Training Loss: 0.01102201 	Validation Loss 0.01334844 	Training Acuuarcy 87.900% 	Validation Acuuarcy 62.891%
# Epoch: 1958 	Training Loss: 0.01104828 	Validation Loss 0.01332345 	Training Acuuarcy 87.529% 	Validation Acuuarcy 64.122%
# Epoch: 1959 	Training Loss: 0.01104367 	Validation Loss 0.01328378 	Training Acuuarcy 87.526% 	Validation Acuuarcy 63.947%
# Epoch: 1960 	Training Loss: 0.01103990 	Validation Loss 0.01336091 	Training Acuuarcy 87.660% 	Validation Acuuarcy 63.349%
# Epoch: 1961 	Training Loss: 0.01104499 	Validation Loss 0.01332404 	Training Acuuarcy 87.539% 	Validation Acuuarcy 63.735%
# Epoch: 1962 	Training Loss: 0.01104049 	Validation Loss 0.01330796 	Training Acuuarcy 87.549% 	Validation Acuuarcy 63.630%
# Epoch: 1963 	Training Loss: 0.01103683 	Validation Loss 0.01329809 	Training Acuuarcy 87.617% 	Validation Acuuarcy 64.122%
# Epoch: 1964 	Training Loss: 0.01104007 	Validation Loss 0.01340203 	Training Acuuarcy 87.731% 	Validation Acuuarcy 62.926%
# Epoch: 1965 	Training Loss: 0.01104466 	Validation Loss 0.01336832 	Training Acuuarcy 87.617% 	Validation Acuuarcy 63.454%
# Epoch: 1966 	Training Loss: 0.01104468 	Validation Loss 0.01334686 	Training Acuuarcy 87.546% 	Validation Acuuarcy 63.630%
# Epoch: 1967 	Training Loss: 0.01104106 	Validation Loss 0.01335254 	Training Acuuarcy 87.607% 	Validation Acuuarcy 62.997%
# Epoch: 1968 	Training Loss: 0.01103620 	Validation Loss 0.01336740 	Training Acuuarcy 87.610% 	Validation Acuuarcy 63.067%
# Epoch: 1969 	Training Loss: 0.01104449 	Validation Loss 0.01333632 	Training Acuuarcy 87.580% 	Validation Acuuarcy 63.384%
# Epoch: 1970 	Training Loss: 0.01104753 	Validation Loss 0.01330884 	Training Acuuarcy 87.576% 	Validation Acuuarcy 63.419%
# Epoch: 1971 	Training Loss: 0.01103676 	Validation Loss 0.01334194 	Training Acuuarcy 87.617% 	Validation Acuuarcy 63.841%
# Epoch: 1972 	Training Loss: 0.01104281 	Validation Loss 0.01340167 	Training Acuuarcy 87.573% 	Validation Acuuarcy 62.329%
# Epoch: 1973 	Training Loss: 0.01103364 	Validation Loss 0.01334037 	Training Acuuarcy 87.681% 	Validation Acuuarcy 63.243%
# Epoch: 1974 	Training Loss: 0.01104035 	Validation Loss 0.01331941 	Training Acuuarcy 87.532% 	Validation Acuuarcy 64.509%
# Epoch: 1975 	Training Loss: 0.01105407 	Validation Loss 0.01336478 	Training Acuuarcy 87.327% 	Validation Acuuarcy 63.560%
# Epoch: 1976 	Training Loss: 0.01103913 	Validation Loss 0.01331330 	Training Acuuarcy 87.563% 	Validation Acuuarcy 64.052%
# Epoch: 1977 	Training Loss: 0.01105131 	Validation Loss 0.01339442 	Training Acuuarcy 87.485% 	Validation Acuuarcy 63.102%
# Epoch: 1978 	Training Loss: 0.01103846 	Validation Loss 0.01336607 	Training Acuuarcy 87.529% 	Validation Acuuarcy 63.771%
# Epoch: 1979 	Training Loss: 0.01103935 	Validation Loss 0.01327118 	Training Acuuarcy 87.684% 	Validation Acuuarcy 64.615%
# Epoch: 1980 	Training Loss: 0.01104204 	Validation Loss 0.01336750 	Training Acuuarcy 87.596% 	Validation Acuuarcy 63.384%
# Epoch: 1981 	Training Loss: 0.01103174 	Validation Loss 0.01332082 	Training Acuuarcy 87.664% 	Validation Acuuarcy 63.313%
# Epoch: 1982 	Training Loss: 0.01104034 	Validation Loss 0.01333193 	Training Acuuarcy 87.556% 	Validation Acuuarcy 63.560%
# Epoch: 1983 	Training Loss: 0.01105484 	Validation Loss 0.01331621 	Training Acuuarcy 87.293% 	Validation Acuuarcy 63.947%
# Epoch: 1984 	Training Loss: 0.01104191 	Validation Loss 0.01331741 	Training Acuuarcy 87.586% 	Validation Acuuarcy 64.087%
# Epoch: 1985 	Training Loss: 0.01103605 	Validation Loss 0.01335533 	Training Acuuarcy 87.637% 	Validation Acuuarcy 63.524%
# Epoch: 1986 	Training Loss: 0.01103093 	Validation Loss 0.01332785 	Training Acuuarcy 87.664% 	Validation Acuuarcy 63.349%
# Epoch: 1987 	Training Loss: 0.01103263 	Validation Loss 0.01334629 	Training Acuuarcy 87.583% 	Validation Acuuarcy 64.333%
# Epoch: 1988 	Training Loss: 0.01104878 	Validation Loss 0.01327678 	Training Acuuarcy 87.445% 	Validation Acuuarcy 64.193%
# Epoch: 1989 	Training Loss: 0.01102839 	Validation Loss 0.01334550 	Training Acuuarcy 87.694% 	Validation Acuuarcy 63.806%
# Epoch: 1990 	Training Loss: 0.01103612 	Validation Loss 0.01336462 	Training Acuuarcy 87.489% 	Validation Acuuarcy 63.489%
# Epoch: 1991 	Training Loss: 0.01103082 	Validation Loss 0.01337959 	Training Acuuarcy 87.691% 	Validation Acuuarcy 63.243%
# Epoch: 1992 	Training Loss: 0.01103803 	Validation Loss 0.01326114 	Training Acuuarcy 87.637% 	Validation Acuuarcy 64.931%
# Epoch: 1993 	Training Loss: 0.01104646 	Validation Loss 0.01331231 	Training Acuuarcy 87.529% 	Validation Acuuarcy 63.208%
# Epoch: 1994 	Training Loss: 0.01103564 	Validation Loss 0.01328737 	Training Acuuarcy 87.637% 	Validation Acuuarcy 63.700%
# Epoch: 1995 	Training Loss: 0.01103924 	Validation Loss 0.01333553 	Training Acuuarcy 87.586% 	Validation Acuuarcy 62.786%
# Epoch: 1996 	Training Loss: 0.01104344 	Validation Loss 0.01333349 	Training Acuuarcy 87.620% 	Validation Acuuarcy 63.454%
# Epoch: 1997 	Training Loss: 0.01103016 	Validation Loss 0.01332258 	Training Acuuarcy 87.654% 	Validation Acuuarcy 64.333%
# Epoch: 1998 	Training Loss: 0.01104065 	Validation Loss 0.01333809 	Training Acuuarcy 87.539% 	Validation Acuuarcy 64.369%
# Epoch: 1999 	Training Loss: 0.01104431 	Validation Loss 0.01329048 	Training Acuuarcy 87.526% 	Validation Acuuarcy 63.806%
# Epoch: 2000 	Training Loss: 0.01104062 	Validation Loss 0.01330632 	Training Acuuarcy 87.630% 	Validation Acuuarcy 63.630%
# ===================================Training Finished===================================

# %%
test_dataset= Plain_Dataset(csv_file="data2/test.csv", img_dir = "data2/test/", datatype = 'test', transform = transformation)

# %%
test_loader=   DataLoader(test_dataset,batch_size=batchsize,shuffle = True,num_workers=0)

# %%
test_result = []
test_loss = 0
test_correct = 0
for data,labels in test_loader:
            data, labels = data.to(device), labels.to(device)
            test_outputs = net(data)
            #print(val_outputs[0][3])
            #print(labels[0])
            t_loss = criterion(test_outputs, labels)
            test_loss += t_loss.item()
            _, test_preds = torch.max(test_outputs,1)
            test_result.append(torch.max(test_outputs,1))
            test_correct += torch.sum(test_preds == labels.data)
# Out:
# /home/youssef/.local/lib/python3.8/site-packages/torch/nn/functional.py:4358: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(
# /home/youssef/.local/lib/python3.8/site-packages/torch/nn/functional.py:4296: UserWarning: Default grid_sample and affine_grid behavior has changed to align_corners=False since 1.3.0. Please specify align_corners=True if the old behavior is desired. See the documentation of grid_sample for details.
#   warnings.warn(

# %%
print("Final accuracy on the testing set = ", test_correct/7099)
# Out:
# Final accuracy on the testing set =  tensor(0.6407)

# %%
from sklearn.metrics import confusion_matrix
import seaborn as sn
import pandas as pd

y_pred = []
y_true = []
for inputs, labels in test_loader:
        output = net(inputs) # Feed Network

        output = (torch.max(torch.exp(output), 1)[1]).data.cpu().numpy()
        y_pred.extend(output) # Save Prediction

        labels = labels.data.cpu().numpy()
        y_true.extend(labels) # Save Truth

# %%
test_result = []
test_loss = 0
test_correct = 0
for data,labels in test_loader:
            data, labels = data.to(device), labels.to(device)
            test_outputs = net(data)
            #print(val_outputs[0][3])
            #print(labels[0])
            t_loss = criterion(test_outputs, labels)
            test_loss += t_loss.item()
            _, test_preds = torch.max(test_outputs,1)
            test_result.append(torch.max(test_outputs,1))
            test_correct += torch.sum(test_preds == labels.data)

# %%
classes = ('Anger', 'Contempt', 'Disgust', 'Fear', 'Happiness',
        'Neutral', 'Sadness', 'Surprise')

# %%
import matplotlib.pyplot as plt
cf_matrix = confusion_matrix(y_true, y_pred)
df_cm = pd.DataFrame(cf_matrix / np.sum(cf_matrix, axis=1)[:, None], index = [i for i in classes],
                     columns = [i for i in classes])
plt.figure(figsize = (12,7))
sn.heatmap(df_cm, annot=True)
plt.savefig('output.png')
